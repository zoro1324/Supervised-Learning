# %%
# !pip install matplotlib numpy pandas seaborn

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv(r"data\Concrete Compressive Strength.csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   cement                    1030 non-null   float64
#  1   slag                      1030 non-null   float64
#  2   ash                       1030 non-null   float64
#  3   water                     1030 non-null   float64
#  4   superplastic              1030 non-null   float64
#  5   coarseagg                 1030 non-null   float64
#  6   fineagg                   1030 non-null   float64
#  7   age                       1030 non-null   int64
#  8   strength                  1030 non-null   float64
#  9   water_cement_ratio        1030 non-null   float64
#  10  total_binder              1030 non-null   float64
#  11  aggregate_to_cement       1030 non-null   float64
#  12  cement_water_interaction  1030 non-null   float64
#  13  age_strength_proxy        1030 non-null   float64
# dtypes: float64(13), int64(1)
# memory usage: 112.8 KB

# %%
data.describe()
# Out:
#             cement         slag          ash        water  superplastic  \
# count  1030.000000  1030.000000  1030.000000  1030.000000   1030.000000
# mean    281.167864    73.895825    54.188350   181.567282      6.204660
# std     104.506364    86.279342    63.997004    21.354219      5.973841
# min     102.000000     0.000000     0.000000   121.800000      0.000000
# 25%     192.375000     0.000000     0.000000   164.900000      0.000000
# 50%     272.900000    22.000000     0.000000   185.000000      6.400000
# 75%     350.000000   142.950000   118.300000   192.000000     10.200000
# max     540.000000   359.400000   200.100000   247.000000     32.200000
#
#          coarseagg      fineagg          age     strength  water_cement_ratio  \
# count  1030.000000  1030.000000  1030.000000  1030.000000         1030.000000
# mean    972.918932   773.580485    45.662136    35.817961            0.748263
# std      77.753954    80.175980    63.169912    16.705742            0.314003
# min     801.000000   594.000000     1.000000     2.330000            0.266892
# 25%     932.000000   730.950000     7.000000    23.710000            0.533332
# 50%     968.000000   779.500000    28.000000    34.445000            0.675346
# 75%    1029.400000   824.000000    56.000000    46.135000            0.935160
# max    1145.000000   992.600000   365.000000    82.600000            1.882334
#
#        total_binder  aggregate_to_cement  cement_water_interaction  \
# count   1030.000000          1030.000000               1030.000000
# mean     409.252039             7.199021              50868.988301
# std       92.780669             2.882574              19585.735383
# min      200.000000             3.097753              19584.000000
# 25%      336.425000             4.875033              33438.440000
# 50%      391.300000             6.535102              48816.240000
# 75%      483.700000             9.240795              63552.000000
# max      640.000000            17.931197             108300.000000
#
#        age_strength_proxy
# count         1030.000000
# mean             5.774836
# std              3.510750
# min              1.000000
# 25%              2.645751
# 50%              5.291503
# 75%              7.483315
# max             19.104973

# %%
data.head()
# Out:
#    cement   slag    ash  water  superplastic  coarseagg  fineagg  age  \
# 0   141.3  212.0    0.0  203.5           0.0      971.8    748.5   28
# 1   168.9   42.2  124.3  158.3          10.8     1080.8    796.2   14
# 2   250.0    0.0   95.7  187.4           5.5      956.9    861.2   28
# 3   266.0  114.0    0.0  228.0           0.0      932.0    670.0   28
# 4   154.8  183.4    0.0  193.3           9.1     1047.4    696.7   28
#
#    strength  water_cement_ratio  total_binder  aggregate_to_cement  \
# 0     29.89            1.440188         353.3            12.174719
# 1     23.51            0.937235         335.4            11.113019
# 2     29.22            0.749597         345.7             7.272371
# 3     45.85            0.857140         380.0             6.022534
# 4     18.29            1.248700         338.2            11.266723
#
#    cement_water_interaction  age_strength_proxy
# 0                  28754.55            5.291503
# 1                  26736.87            3.741657
# 2                  46850.00            5.291503
# 3                  60648.00            5.291503
# 4                  29922.84            5.291503

# %%
sns.pairplot(data)

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >

# %%
x = data.drop(columns='strength')
y = data['strength']

# %%
from sklearn.feature_selection import SelectKBest
selector = SelectKBest(k=12)
x_selected = selector.fit_transform(x, y)
selected_features = selector.get_support()
x = x.loc[:, selected_features]
x
# Out:
#       cement   slag    ash  water  superplastic  coarseagg  fineagg  \
# 0      141.3  212.0    0.0  203.5           0.0      971.8    748.5
# 1      168.9   42.2  124.3  158.3          10.8     1080.8    796.2
# 2      250.0    0.0   95.7  187.4           5.5      956.9    861.2
# 3      266.0  114.0    0.0  228.0           0.0      932.0    670.0
# 4      154.8  183.4    0.0  193.3           9.1     1047.4    696.7
# ...      ...    ...    ...    ...           ...        ...      ...
# 1025   135.0    0.0  166.0  180.0          10.0      961.0    805.0
# 1026   531.3    0.0    0.0  141.8          28.2      852.1    893.7
# 1027   276.4  116.0   90.3  179.6           8.9      870.1    768.3
# 1028   342.0   38.0    0.0  228.0           0.0      932.0    670.0
# 1029   540.0    0.0    0.0  173.0           0.0     1125.0    613.0
#
#       water_cement_ratio  total_binder  aggregate_to_cement  \
# 0               1.440188         353.3            12.174719
# 1               0.937235         335.4            11.113019
# 2               0.749597         345.7             7.272371
# 3               0.857140         380.0             6.022534
# 4               1.248700         338.2            11.266723
# ...                  ...           ...                  ...
# 1025            1.333323         301.0            13.081385
# 1026            0.266892         531.3             3.285896
# 1027            0.649781         482.7             5.927620
# 1028            0.666665         380.0             4.684197
# 1029            0.320370         540.0             3.218513
#
#       cement_water_interaction  age_strength_proxy
# 0                     28754.55            5.291503
# 1                     26736.87            3.741657
# 2                     46850.00            5.291503
# 3                     60648.00            5.291503
# 4                     29922.84            5.291503
# ...                        ...                 ...
# 1025                  24300.00            5.291503
# 1026                  75338.34            1.732051
# 1027                  49641.44            5.291503
# 1028                  77976.00           16.431677
# 1029                  93420.00            2.645751
#
# [1030 rows x 12 columns]

# %%
for col in x.columns:
    sns.boxplot(data=x[col])
    plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y)

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
model.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
print("r2 score :",r2_score(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
print("MSE:",mean_squared_error(y_test,y_pred))
# Out:
# r2 score : 0.8391743096776131
# MAE: 4.28298449612403
# MSE: 43.3162949612403

# %%
from sklearn import tree
plt.figure(figsize=(30,15))
tree.plot_tree(model,max_depth=3, filled=True)
plt.show()
